# %%
import cv2
import numpy as np
import urllib.request
from matplotlib import pyplot as plt


url = "https://images.unsplash.com/photo-1502741338009-cac2772e18bc?w=800"

headers = {'User-Agent': 'Mozilla/5.0'}
req = urllib.request.Request(url, headers=headers)
resp = urllib.request.urlopen(req)
image_array = np.asarray(bytearray(resp.read()), dtype=np.uint8)
img = cv2.imdecode(image_array, cv2.IMREAD_COLOR)


plt.figure(figsize=(6, 4))
plt.title("obraz")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()


height, width = img.shape[:2]
new_size = (width // 2, height // 2)
img_resized = cv2.resize(img, new_size)


gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)

rotated = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)

plt.figure(figsize=(5, 5))
plt.title("Obraz po przetworzeniu")
plt.imshow(rotated, cmap='gray')
plt.axis('off')
plt.show()

print("Macierz obrazu (fragment):")
print(rotated[:10, :10])
print(f"\nWymiary obrazu po przetworzeniu: {rotated.shape}")
# Out:
# Macierz obrazu (fragment):
# [[33 36 36 38 39 40 40 40 41 39]
#  [31 32 34 36 37 38 38 39 38 36]
#  [32 29 30 33 35 36 37 38 36 35]
#  [35 28 27 29 31 33 34 34 34 34]
#  [42 27 25 27 28 29 30 31 32 32]
#  [46 30 24 24 25 26 27 28 28 29]
#  [52 34 21 20 21 23 24 25 25 25]
#  [59 40 23 17 18 19 20 21 22 22]
#  [63 44 24 14 16 17 17 19 20 20]
#  [64 45 25 15 15 15 16 17 17 17]]
#
# Wymiary obrazu po przetworzeniu: (400, 267)
